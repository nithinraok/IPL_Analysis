# %%
import pandas as pd
import numpy as np
import pickle as pkl
# %matplotlib inline

# %%
PATH = '../../ipl/'

# %%
deliveries = pd.read_csv(f'{PATH}deliveries.csv')

# %%
RCB = 'Royal Challengers Bangalore'
MI = 'Mumbai Indians'
CSK = 'Chennai Super Kings'
SRH = 'Sunrisers Hyderabad'
KKR = 'Kolkata Knight Riders'
RR =  'Rajasthan Royals'
DD = 'Delhi Daredevils'
KXIP = 'Kings XI Punjab'

# %%
matches = pd.read_csv(f'{PATH}newmatches.csv',index_col=0)

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %%
BatsmenBalls=pkl.load(open(f'{PATH}BatsmenBallsDataFrame.pkl','rb'))

# %%
BatsmenRuns=pkl.load(open(f'{PATH}BatsmenRunsDataFrame.pkl','rb'))

# %%
[name for name in BatsmenRuns.index.values if 'Tahir' in name]
# Out:
# ['Imran Tahir']

# %%
Team1=['V Kohli','AB de Villiers','Q de Kock','CJ Anderson','C de Grandhomme'
      ,'Mandeep Singh','P Negi','Washington Sundar','YS Chahal','UT Yadav','Mohammed Siraj']

# %%
Team2=['SR Watson','AT Rayudu','SK Raina','MS Dhoni','SW Billings','RA Jadeja','DJ Bravo'
      ,'Harbhajan Singh','DL Chahar','SN Thakur','Imran Tahir']

# %%
Batsmen=Team1[:6]

# %%
Batsmen=Team2[:6]

# %%
Batsmen
# Out:
# ['SR Watson', 'AT Rayudu', 'SK Raina', 'MS Dhoni', 'SW Billings', 'RA Jadeja']

# %%
Bowlers=[Team1[i] for i in [3,4,6,7,8,9,10]]

# %%
Bowlers
# Out:
# ['CJ Anderson',
#  'C de Grandhomme',
#  'P Negi',
#  'Washington Sundar',
#  'YS Chahal',
#  'UT Yadav',
#  'Mohammed Siraj']

# %%
RunsScored=BatsmenRuns.T[BatsmenRuns.T.index.isin(Bowlers)].T[BatsmenRuns.index.isin(Batsmen)]

# %%
BallsFaced=BatsmenBalls.T[BatsmenBalls.T.index.isin(Bowlers)].T[BatsmenBalls.index.isin(Batsmen)]

# %%
RunsScored
# Out:
#             YS Chahal P Negi CJ Anderson UT Yadav C de Grandhomme  \
# AT Rayudu          31     11           0       33               0
# MS Dhoni           35     11          10       33               0
# RA Jadeja          17      1          15        9               0
# SK Raina           79     24           7       80               0
# SR Watson          24     17           2       41               0
# SW Billings        13      0           0       11               0
#
#             Mohammed Siraj Washington Sundar
# AT Rayudu                0                 1
# MS Dhoni                22                 0
# RA Jadeja                3                 0
# SK Raina                 1                 0
# SR Watson                0                 0
# SW Billings             12                 0

# %%
BallsFaced
# Out:
#             YS Chahal P Negi CJ Anderson UT Yadav C de Grandhomme  \
# AT Rayudu          30      6           0       25               0
# MS Dhoni           31     15           7       26               0
# RA Jadeja          13      8           4        9               0
# SK Raina           57     13           5       76               0
# SR Watson          21     17           5       22               0
# SW Billings         9      0           0        8               0
#
#             Mohammed Siraj Washington Sundar
# AT Rayudu                0                 6
# MS Dhoni                12                 0
# RA Jadeja                2                 0
# SK Raina                 3                 0
# SR Watson                0                 0
# SW Billings              5                 0

# %%
(RunsScored/(BallsFaced+1))*100
# Out:
#                 SR Watson DL Chahar Imran Tahir Harbhajan Singh RA Jadeja  \
# AB de Villiers    106.383        50     130.769         115.942   125.333
# C de Grandhomme         0         0         220               0         0
# CJ Anderson       138.462         0     33.3333         166.667   155.556
# Mandeep Singh          50         0           0              60   92.8571
# Q de Kock          131.25        25           0         94.7368   66.6667
# V Kohli           70.3704     187.5     117.647             130   105.051
#
#                 SN Thakur DJ Bravo
# AB de Villiers        125  153.333
# C de Grandhomme        50        0
# CJ Anderson             0        0
# Mandeep Singh           0       75
# Q de Kock               0        0
# V Kohli           177.778  141.304

# %%
RunsScored.astype('str') + ' ( ' + BallsFaced.astype('str') + ')'
# Out:
#             YS Chahal    P Negi CJ Anderson  UT Yadav C de Grandhomme  \
# AT Rayudu    31 ( 30)   11 ( 6)      0 ( 0)  33 ( 25)          0 ( 0)
# MS Dhoni     35 ( 31)  11 ( 15)     10 ( 7)  33 ( 26)          0 ( 0)
# RA Jadeja    17 ( 13)    1 ( 8)     15 ( 4)    9 ( 9)          0 ( 0)
# SK Raina     79 ( 57)  24 ( 13)      7 ( 5)  80 ( 76)          0 ( 0)
# SR Watson    24 ( 21)  17 ( 17)      2 ( 5)  41 ( 22)          0 ( 0)
# SW Billings   13 ( 9)    0 ( 0)      0 ( 0)   11 ( 8)          0 ( 0)
#
#             Mohammed Siraj Washington Sundar
# AT Rayudu           0 ( 0)            1 ( 6)
# MS Dhoni          22 ( 12)            0 ( 0)
# RA Jadeja           3 ( 2)            0 ( 0)
# SK Raina            1 ( 3)            0 ( 0)
# SR Watson           0 ( 0)            0 ( 0)
# SW Billings        12 ( 5)            0 ( 0)

# %%
RunsScored.sum().sum()
# Out:
# 543.0

# %%
(RunsScored.sum().sum()/BallsFaced.sum().sum())*6*20
# Out:
# 149.79310344827587
