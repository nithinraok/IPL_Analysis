# %%
PATH = '../ipl/'

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
deliveries=pd.read_csv(f'{PATH}deliveries.csv')

# %%
matches = pd.read_csv(f'{PATH}matches.csv')

# %%
print(matches.season.unique())
# Out:
# [2017 2008 2009 2010 2011 2012 2013 2014 2015 2016]

# %%
matches
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over   ...    bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0   ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0   ...           0
# 2     3  DA Warner    S Dhawan  TS Mills              0   ...           0
# 3     4  DA Warner    S Dhawan  TS Mills              0   ...           0
# 4     5  DA Warner    S Dhawan  TS Mills              0   ...           0
#
# ...

# %%
RCB = 'Royal Challengers Bangalore'
MI = 'Mumbai Indians'
CSK = 'Chennai Super Kings'
SRH = 'Sunrisers Hyderabad'
KKR = 'Kolkata Knight Riders'
RR =  'Rajasthan Royals'
DD = 'Delhi Daredevils'
KXIP = 'Kings XI Punjab'

# %%
RCBmask= (matches.team1 == 'Royal Challengers Bangalore') | (matches.team2 == 'Royal Challengers Bangalore');
RPSmask1= (matches.team1 == 'Rising Pune Supergiant') | (matches.team2 == 'Rising Pune Supergiant');
KKRmask= (matches.team1 == 'Kolkata Knight Riders') | (matches.team2 == 'Kolkata Knight Riders');
SRHmask= (matches.team1 == 'Sunrisers Hyderabad') | (matches.team2 == 'Sunrisers Hyderabad');
KXIPmask= (matches.team1 == 'Kings XI Punjab') | (matches.team2 == 'Kings XI Punjab');
MImask= (matches.team1 == 'Mumbai Indians') | (matches.team2 == 'Mumbai Indians');
DDmask= (matches.team1 == 'Delhi Daredevils') | (matches.team2 == 'Delhi Daredevils');
GLmask= (matches.team1 == 'Gujarat Lions') | (matches.team2 == 'Gujarat Lions');
CSKmask= (matches.team1 == 'Chennai Super Kings') | (matches.team2 == 'Chennai Super Kings');
RRmask= (matches.team1 == 'Rajasthan Royals') | (matches.team2 == 'Rajasthan Royals');
DCmask= (matches.team1 == 'Deccan Chargers') | (matches.team2 == 'Deccan Chargers');
PWmask= (matches.team1 == 'Pune Warriors') | (matches.team2 == 'Pune Warriors');
KTKmask= (matches.team1 == 'Kochi Tuskers Kerala') | (matches.team2 == 'Kochi Tuskers Kerala');
RPSmask2= (matches.team1 == 'Rising Pune Supergiants') | (matches.team2 == 'Rising Pune Supergiants');

# %%
MImask.value_counts()[:2][1]  #Played by MI
# Out:
# 157

# %%
matches.city.unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan],
#       dtype=object)

# %%
matches.winner.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Mumbai Indians',
#        'Delhi Daredevils', 'Gujarat Lions', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Deccan Chargers', 'Pune Warriors',
#        'Kochi Tuskers Kerala', nan, 'Rising Pune Supergiants'],
#       dtype=object)

# %%
## RCB win matches,matches won at home and win%
Team = RCB;
mask = RCBmask;
homecity = 'Bangalore'
len(matches[matches.winner==Team]), len(matches[(matches.winner==Team) & (matches.city == homecity)]), (len(matches[matches.winner==Team])/len(matches[mask]))*100
# Out:
# (73, 30, 48.026315789473685)

# %%
## CSK win matches,matches won at home and win%
Team = CSK;
mask = CSKmask;
homecity = 'Chennai'
len(matches[matches.winner==Team]), len(matches[(matches.winner==Team) & (matches.city == homecity)]), (len(matches[matches.winner==Team])/len(matches[mask]))*100
# Out:
# (79, 33, 60.30534351145038)

# %%
## SRH win matches,matches won at home and win%
Team = SRH;
mask = SRHmask;
homecity = 'Hyderabad'
len(matches[matches.winner==Team]), len(matches[(matches.winner==Team) & (matches.city == homecity)]), (len(matches[matches.winner==Team])/len(matches[mask]))*100
# Out:
# (42, 20, 55.26315789473685)

# %%
## MI win matches,matches won at home and win%
Team = MI;
mask = MImask;
homecity = 'Mumbai'
len(matches[matches.winner==Team]), len(matches[(matches.winner==Team) & (matches.city == homecity)]), (len(matches[matches.winner==Team])/len(matches[mask]))*100
# Out:
# (92, 45, 58.59872611464968)

# %%
## KKR win matches,matches won at home and win%
Team = KKR;
mask = KKRmask;
homecity = 'Kolkata'
len(matches[matches.winner==Team]), len(matches[(matches.winner==Team) & (matches.city == homecity)]), (len(matches[matches.winner==Team])/len(matches[mask]))*100
# Out:
# (77, 37, 52.02702702702703)

# %%
len(matches[(matches.team1 == Team) | (matches.team2 == Team)])
# Out:
# 152

# %%
## RCB win matches,matches won at home and win%
Team = DD;
mask = DDmask;
homecity = 'Delhi'
len(matches[matches.winner==Team]), len(matches[(matches.winner==Team) & (matches.city == homecity)]), (len(matches[matches.winner==Team])/len(matches[mask]))*100
# Out:
# (62, 23, 42.17687074829932)

# %%
## RCB win matches,matches won at home and win%
Team = RR;
mask = RRmask;
homecity = 'Jaipur'
len(matches[matches.winner==Team]), len(matches[(matches.winner==Team) & (matches.city == homecity)]), (len(matches[matches.winner==Team])/len(matches[mask]))*100
# Out:
# (63, 24, 53.38983050847458)

# %%
## RCB win matches,matches won at home and win%
Team = KXIP;
mask = KXIPmask;
homecity = 'Dharamsala'
len(matches[matches.winner==Team]), len(matches[(matches.winner==Team) & (matches.city == homecity)]), (len(matches[matches.winner==Team])/len(matches[mask]))*100
# Out:
# (70, 5, 47.2972972972973)

# %%
deliveries
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
sixesHit = (deliveries[deliveries.batsman_runs==6]);

# %%
len(sixesHit)
# Out:
# 6523

# %%
sixBatsmens=list(sixesHit.batsman);

# %%
pd.Series(sixBatsmens).value_counts()
# Out:
# CH Gayle           266
# SK Raina           174
# RG Sharma          173
# DA Warner          160
# V Kohli            160
# AB de Villiers     158
# MS Dhoni           156
# YK Pathan          149
# KA Pollard         148
# Yuvraj Singh       141
# RV Uthappa         125
# BB McCullum        124
# SR Watson          122
# DR Smith           117
# V Sehwag           106
# AC Gilchrist        92
# M Vijay             89
# GJ Maxwell          82
# AT Rayudu           79
# NV Ojha             79
# SE Marsh            78
# JP Duminy           78
# DA Miller           78
# KD Karthik          71
# S Dhawan            71
# MK Pandey           65
# AM Rahane           60
# DJ Hussey           60
# AJ Finch            59
# G Gambhir           58
#                   ...
# RJ Peterson          1
# AB Barath            1
# A Mithun             1
# AC Thomas            1
# K Rabada             1
# MA Khote             1
# JJ van der Wath      1
# BJ Haddin            1
# SK Trivedi           1
# ...

# %%
len(sixBatsmens)
# Out:
# 6523

# %%
shaneWatson = deliveries[deliveries.batsman=='SR Watson'];

# %%
batsmanRuns=deliveries.groupby('batsman').sum();

# %%
batsmanRuns.batsman_runs.sum()
# Out:
# 183929

# %%
batsmanRuns.sort_values(by='batsman_runs',ascending=0)
# Out:
#            match_id  inning   over   ball  is_super_over  wide_runs  bye_runs  \
# batsman
# SK Raina    1079285    4748  32746  12256              3        124         0
# V Kohli     1304291    5112  33426  12284              2        110         5
# RG Sharma   1081920    4822  36662  11601              0         66         2
# G Gambhir   1072760    5510  23650  12313              0        151        10
# DA Warner   1085379    4258  21153  10188              1        108        23
#
#            legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# batsman
# SK Raina            57           16             0          4548         197
# V Kohli             39           11             0          4423         165
# RG Sharma           48           11             0          4207         127
# G Gambhir           85           10             0          4132         256
# DA Warner           52           16             0          4014         199
#
# ...

# %%
shaneWatson
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 200            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 203            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 204            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 207            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 210            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 212            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 215            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 219            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 223            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 224            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 225            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# ...

# %%
shaneRecent5matches=matches[(matches.season==2017) & (RCBmask)].head().id

# %%
shaneRecent5matches.values
# Out:
# array([ 1,  5,  8, 12, 17])

# %%
latest5matchRuns=[shaneWatson[shaneWatson.match_id == ids].groupby('batsman').sum().batsman_runs.values for ids in shaneRecent5matches.values]

# %%
print(latest5matchRuns)
# Out:
# [array([22]), array([24]), array([1]), array([], dtype=int64), array([14])]

# %%
22+24+1+14
# Out:
# 61

# %%
len(matches[CSKmask])
# Out:
# 131

# %%
matches[matches.season==2014].id.values[-1]
# Out:
# 517

# %%
Year = 2008

a=matches[matches.season==Year].id.values[0]-1
b=matches[matches.season==Year].id.values[-1]

deliveries.groupby('match_id').sum()[a:b].batsman_runs.sum()
# Out:
# 16809
